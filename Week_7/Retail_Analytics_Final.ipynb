# %%
# import libraries
from cryptography.fernet import Fernet
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import warnings
warnings.filterwarnings('ignore')

# %%
# open the key
with open('filekey.key', 'rb') as f:
  key = f.read()

# %%
# Store it in fernet
fernet = Fernet(key)

# %%
# Open the data
with open('Online Retail.xlsx', 'rb') as f:
  data = f.read()

# %%
# Decryption
decrypt_data = fernet.decrypt(data)

# %%
# Overwrite the data
with open('Online Retail.xlsx', 'wb') as f:
  f.write(decrypt_data)

# %%
# Load the data in pandas Dataframe
df = pd.read_excel('Online Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Shape of the data
df.shape
# Out:
# (541909, 8)

# %%
# Copy of the data
df_copy = df.copy(deep = True)
df_copy.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Create a new column
df_copy['Sales'] = df_copy['Quantity'] * df_copy['UnitPrice']

# %%
# Check the columns
df_copy.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Sales'],
#       dtype='object')

# %%
# Missing Values
df_copy.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# Sales               0
# dtype: int64

# %%
# Unique Values in Description Column
df_copy['Description'].nunique()
# Out:
# 4223

# %%
# Clear the white spaces
df_copy['Description'] = df_copy['Description'].str.strip()

# %%
# Check again the Unique Values
df_copy['Description'].nunique()
# Out:
# 4210

# %%
# Price to Description Maping
price_to_description_map = df_copy.dropna(subset=['Description']).drop_duplicates(subset=['UnitPrice'], keep= 'first').set_index('UnitPrice')['Description']

# %%
# fill the missing values
df_copy['Description'] = df_copy['Description'].fillna(df_copy['UnitPrice'].map(price_to_description_map))

# %%
# Check if Missing Values are replaced
df_copy.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# Sales               0
# dtype: int64

# %%
# Show the Cancelled Invoices
df_copy[df_copy['InvoiceNo'].astype(str).str.contains('C')].head()
# Out:
#     InvoiceNo StockCode                      Description  Quantity  \
# 141   C536379         D                         Discount        -1
# 154   C536383    35004C  SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE       -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES       -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES       -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Sales
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom -27.50
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom  -4.65
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom -19.80
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom  -6.96
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom  -6.96

# %%
# We want to Exclude the cancelled invoices for Market Basket Analysis
df_copy['InvoiceNo'] = df_copy['InvoiceNo'].astype(str)
df_new = df_copy[~df_copy['InvoiceNo'].str.contains('C')]
df_new.shape
# Out:
# (532621, 9)

# %%
# Lets explore the new data
df_new.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Sales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34

# %%
# Unique Countries
df_new['Country'].nunique()
# Out:
# 38

# %%
# Which Country Gives Us More Sales
df_new.groupby('Country')['Sales'].sum().sort_values(ascending = False).head()
# Out:
# Country
# United Kingdom    9003097.964
# Netherlands        285446.340
# EIRE               283453.960
# Germany            228867.140
# France             209715.110
# Name: Sales, dtype: float64

# %%
# Unstancking the Description and Resetting the Index
grouped_df = df_new[df_new['Country'] == 'France'].groupby(['InvoiceNo', 'Description']).size().unstack().fillna(0).reset_index().set_index('InvoiceNo')
grouped_df.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# 536852                                 0.0
# 536974                                 0.0
# 537065                                 0.0
# 537463                                 0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                       0.0                          0.0
# 536852                                       0.0                          0.0
# 536974                                       0.0                          0.0
# 537065                                       0.0                          0.0
# 537463                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                             0.0                                 0.0
# 536852                             0.0                                 0.0
# 536974                             0.0                                 0.0
# 537065                             0.0                                 0.0
# 537463                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                 0.0  ...                          0.0
# 536852                                 0.0  ...                          0.0
# 536974                                 0.0  ...                          0.0
# 537065                                 0.0  ...                          0.0
# 537463                                 0.0  ...                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                           0.0                        0.0
# 536852                           0.0                        0.0
# 536974                           0.0                        0.0
# 537065                           0.0                        0.0
# 537463                           0.0                        0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                             0.0                         0.0
# 536852                             0.0                         0.0
# 536974                             0.0                         0.0
# 537065                             0.0                         0.0
# 537463                             0.0                         0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                               0.0                             0.0
# 536852                               0.0                             0.0
# 536974                               0.0                             0.0
# 537065                               0.0                             0.0
# 537463                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                   0.0
# 536852                                   0.0
# 536974                                   0.0
# 537065                                   0.0
# 537463                                   0.0
#
# [5 rows x 1563 columns]

# %%
# Defining a Custom Encoding
def custom_encoding(x):
  if x<=0:
    return 0
  elif x>=1:
    return 1
grouped_df = grouped_df.applymap(custom_encoding)
grouped_df.drop('POSTAGE', inplace = True, axis =1)

# %%
# Market Basket Analysis
frequent_items = apriori(grouped_df, min_support = 0.05, use_colnames= True)

# %%
# Rules
rules = association_rules(frequent_items, metric= 'confidence', min_threshold=0.6)

# %%
# Sort
rules.sort_values(by = 'lift', ascending= False)
# Out:
#                                           antecedents  \
# 10                       (PACK OF 6 SKULL PAPER CUPS)
# 11                     (PACK OF 6 SKULL PAPER PLATES)
# 7                      (CHILDRENS CUTLERY DOLLY GIRL)
# 6                        (CHILDRENS CUTLERY SPACEBOY)
# 25  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 26                         (ALARM CLOCK BAKELIKE RED)
# 24  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...
# 27                       (ALARM CLOCK BAKELIKE GREEN)
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 23  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...
# 28                        (ALARM CLOCK BAKELIKE PINK)
# 5                         (ALARM CLOCK BAKELIKE PINK)
# 4                          (ALARM CLOCK BAKELIKE RED)
# 37                    (SET/6 RED SPOTTY PAPER PLATES)
# 32  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE PINK)
# 33  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 36                      (SET/6 RED SPOTTY PAPER CUPS)
# 21                      (SET/6 RED SPOTTY PAPER CUPS)
# 22                    (SET/6 RED SPOTTY PAPER PLATES)
# 34  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 35               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 20                    (SET/6 RED SPOTTY PAPER PLATES)
# 19               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 8                              (DOLLY GIRL LUNCH BOX)
# 18                      (SET/6 RED SPOTTY PAPER CUPS)
# 17               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 9                       (LUNCH BAG DOLLY GIRL DESIGN)
# 31  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 29  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN CIR...
# 16                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 15                         (PLASTERS IN TIN SPACEBOY)
# 13                        (PLASTERS IN TIN STRONGMAN)
# 30  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...
# 12                         (PLASTERS IN TIN SPACEBOY)
# 14                    (PLASTERS IN TIN CIRCUS PARADE)
#
#                                           consequents  antecedent support  \
# 10                     (PACK OF 6 SKULL PAPER PLATES)            0.063776
# 11                       (PACK OF 6 SKULL PAPER CUPS)            0.056122
# 7                        (CHILDRENS CUTLERY SPACEBOY)            0.071429
# 6                      (CHILDRENS CUTLERY DOLLY GIRL)            0.068878
# 25                         (ALARM CLOCK BAKELIKE RED)            0.073980
# 26  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...            0.094388
# 24                       (ALARM CLOCK BAKELIKE GREEN)            0.073980
# 27  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...            0.096939
# 2                        (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 3                          (ALARM CLOCK BAKELIKE RED)            0.096939
# 23                        (ALARM CLOCK BAKELIKE PINK)            0.079082
# 28  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...            0.102041
# 5                          (ALARM CLOCK BAKELIKE RED)            0.102041
# 4                         (ALARM CLOCK BAKELIKE PINK)            0.094388
# 37  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.127551
# 32                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 0                         (ALARM CLOCK BAKELIKE PINK)            0.096939
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.102041
# 33                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 36  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.137755
# 21                    (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 22                      (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 34               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
# 35  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...            0.132653
# 20               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 19                    (SET/6 RED SPOTTY PAPER PLATES)            0.132653
# 8                                (SPACEBOY LUNCH BOX)            0.099490
# 18               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.137755
# 17                      (SET/6 RED SPOTTY PAPER CUPS)            0.132653
# 9                         (LUNCH BAG SPACEBOY DESIGN)            0.084184
# 31                         (PLASTERS IN TIN SPACEBOY)            0.102041
# 29                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.089286
# 16                         (PLASTERS IN TIN SPACEBOY)            0.170918
# 15                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.137755
# 13                    (PLASTERS IN TIN CIRCUS PARADE)            0.081633
# 30                    (PLASTERS IN TIN CIRCUS PARADE)            0.104592
# 12                    (PLASTERS IN TIN CIRCUS PARADE)            0.137755
# 14                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.168367
#
#     consequent support   support  confidence       lift  representativity  \
# 10            0.056122  0.051020    0.800000  14.254545               1.0
# 11            0.063776  0.051020    0.909091  14.254545               1.0
# 7             0.068878  0.063776    0.892857  12.962963               1.0
# 6             0.071429  0.063776    0.925926  12.962963               1.0
# 25            0.094388  0.063776    0.862069   9.133271               1.0
# 26            0.073980  0.063776    0.675676   9.133271               1.0
# 24            0.096939  0.063776    0.862069   8.892922               1.0
# 27            0.073980  0.063776    0.657895   8.892922               1.0
# 2             0.096939  0.079082    0.837838   8.642959               1.0
# 3             0.094388  0.079082    0.815789   8.642959               1.0
# 23            0.102041  0.063776    0.806452   7.903226               1.0
# 28            0.079082  0.063776    0.625000   7.903226               1.0
# 5             0.094388  0.073980    0.725000   7.681081               1.0
# 4             0.102041  0.073980    0.783784   7.681081               1.0
# 37            0.102041  0.099490    0.780000   7.644000               1.0
# 32            0.127551  0.099490    0.975000   7.644000               1.0
# 0             0.102041  0.073980    0.763158   7.478947               1.0
# 1             0.096939  0.073980    0.725000   7.478947               1.0
# 33            0.137755  0.099490    0.975000   7.077778               1.0
# 36            0.102041  0.099490    0.722222   7.077778               1.0
# 21            0.127551  0.122449    0.888889   6.968889               1.0
# 22            0.137755  0.122449    0.960000   6.968889               1.0
# 34            0.132653  0.099490    0.812500   6.125000               1.0
# 35            0.122449  0.099490    0.750000   6.125000               1.0
# 20            0.132653  0.102041    0.800000   6.030769               1.0
# 19            0.127551  0.102041    0.769231   6.030769               1.0
# 8             0.125000  0.071429    0.717949   5.743590               1.0
# 18            0.132653  0.102041    0.740741   5.584046               1.0
# 17            0.137755  0.102041    0.769231   5.584046               1.0
# 9             0.119898  0.051020    0.606061   5.054803               1.0
# 31            0.137755  0.068878    0.675000   4.900000               1.0
# 29            0.170918  0.068878    0.771429   4.513433               1.0
# 16            0.137755  0.104592    0.611940   4.442233               1.0
# 15            0.170918  0.104592    0.759259   4.442233               1.0
# 13            0.168367  0.058673    0.718750   4.268939               1.0
# 30            0.168367  0.068878    0.658537   3.911308               1.0
# 12            0.168367  0.089286    0.648148   3.849607               1.0
# 14            0.170918  0.102041    0.606061   3.545907               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 10  0.047441    4.719388       0.993188  0.740741   0.788108    0.854545
# 11  0.047441   10.298469       0.985135  0.740741   0.902898    0.854545
# 7   0.058856    8.690476       0.993846  0.833333   0.884932    0.909392
# 6   0.058856   12.535714       0.991123  0.833333   0.920228    0.909392
# 25  0.056793    6.565689       0.961653  0.609756   0.847693    0.768872
# 26  0.056793    2.855230       0.983324  0.609756   0.649765    0.768872
# 24  0.056604    6.547194       0.958457  0.595238   0.847263    0.759982
# 27  0.056604    2.706829       0.982825  0.595238   0.630564    0.759982
# 2   0.069932    5.568878       0.976465  0.704545   0.820431    0.826814
# 3   0.069932    4.916181       0.979224  0.704545   0.796590    0.826814
# 23  0.055706    4.639456       0.948476  0.543478   0.784457    0.715726
# 28  0.055706    2.455782       0.972727  0.543478   0.592798    0.715726
# 5   0.064348    3.293135       0.968652  0.604167   0.696338    0.754392
# 4   0.064348    4.153061       0.960466  0.604167   0.759214    0.754392
# 37  0.086474    4.081633       0.996251  0.764706   0.755000    0.877500
# 32  0.086474   34.897959       0.967949  0.764706   0.971345    0.877500
# 0   0.064088    3.791383       0.959283  0.591837   0.736244    0.744079
# 1   0.064088    3.283859       0.964734  0.591837   0.695480    0.744079
# 33  0.085433   34.489796       0.956294  0.709091   0.971006    0.848611
# 36  0.085433    3.232653       0.995904  0.709091   0.690657    0.848611
# 21  0.104878    7.852041       0.993343  0.857143   0.872645    0.924444
# 22  0.104878   21.556122       0.981725  0.857143   0.953609    0.924444
# 34  0.083247    4.625850       0.953488  0.639344   0.783824    0.781250
# 35  0.083247    3.510204       0.964706  0.639344   0.715116    0.781250
# 20  0.085121    4.336735       0.956140  0.645161   0.769412    0.784615
# 19  0.085121    3.780612       0.961765  0.645161   0.735493    0.784615
# 8   0.058992    3.102273       0.917139  0.466667   0.677656    0.644689
# 18  0.083767    3.345481       0.952071  0.606061   0.701089    0.754986
# 17  0.083767    3.736395       0.946471  0.606061   0.732362    0.754986
# 9   0.040927    2.234105       0.875905  0.333333   0.552394    0.515796
# 31  0.054821    2.653061       0.886364  0.402985   0.623077    0.587500
# 29  0.053617    3.627232       0.854757  0.360000   0.724308    0.587207
# 16  0.081047    2.221939       0.934634  0.512500   0.549943    0.685600
# 15  0.081047    3.443878       0.898687  0.512500   0.709630    0.685600
# 13  0.044929    2.956916       0.833816  0.306667   0.661810    0.533617
# 30  0.051268    2.435496       0.831276  0.337500   0.589406    0.533814
# 12  0.066092    2.363588       0.858495  0.411765   0.576914    0.589226
# 14  0.073264    2.104592       0.863344  0.430108   0.524848    0.601538

# %% [markdown]
# OMNI CHANNEL RETAIL DATA

# %%
# Open the key file
with open('file_key.key', 'rb') as f:
  key = f.read()

# %%
# Store it in fernet
fernet = Fernet(key)

# %%
# Open the data
with open('retail_data.csv', 'rb') as f:
  data = f.read()

# %%
# Decrypt the data
decryption = fernet.decrypt(data)

# %%
# Overwrite the data with Decryption
with open('retail_data.csv', 'wb') as f:
  f.write(decryption)

# %%
# Load the data with pandas
retail = pd.read_csv('retail_data.csv')
retail.head()
# Out:
#   visit_id customer_id           visit_date     channel  dwell_seconds  \
# 0  V100029       C0297  2025-06-01 02:35:05  E-Commerce            106
# 1  V100255       C0025  2025-06-01 07:26:34       Store            151
# 2  V100057       C0087  2025-06-01 12:08:39  E-Commerce            710
# 3  V100472       C0046  2025-06-02 00:36:32  E-Commerce             62
# 4  V100454       C0169  2025-06-02 07:42:42         App             44
#
#    is_purchase               items  num_items  total_amount  total_cogs  \
# 0         True          Chips (x1)          1          40.0       23.86
# 1         True  Floor Cleaner (x1)          1         180.0      115.54
# 2        False                 NaN          0           0.0        0.00
# 3        False                 NaN          0           0.0        0.00
# 4        False                 NaN          0           0.0        0.00
#
#    return_flag         fulfillment_status  satisfaction     first_visit_date  \
# 0         True                  Fulfilled           2.0  2025-06-01 02:35:05
# 1        False  In-Store Pickup/Immediate           3.0  2025-06-01 07:26:34
# 2        False                        NaN           NaN  2025-06-01 12:08:39
# 3        False                        NaN           NaN  2025-06-02 00:36:32
# 4        False                        NaN           NaN  2025-06-02 07:42:42
#
#    is_new_customer acquisition_channel     Category
# 0             True          E-Commerce  Electronics
# 1             True               Store   Stationery
# 2             True          E-Commerce          NaN
# 3             True          E-Commerce          NaN
# 4             True                 App          NaN

# %%
# Missing Values
retail.isna().sum()
# Out:
# visit_id                 0
# customer_id              0
# visit_date               0
# channel                  0
# dwell_seconds            0
# is_purchase              0
# items                  391
# num_items                0
# total_amount             0
# total_cogs               0
# return_flag              0
# fulfillment_status     391
# satisfaction           391
# first_visit_date         0
# is_new_customer          0
# acquisition_channel      0
# Category               391
# dtype: int64

# %%
# Missing Data
missing_rows = retail[retail.isna().any(axis=1)]
all_missing_due_to_no_purchase = (missing_rows['is_purchase'] == 0).all()
print("Are all missing values only where no purchase happened? :", all_missing_due_to_no_purchase)
# Out:
# Are all missing values only where no purchase happened? : True

# %%
# Datatypes
retail.dtypes
# Out:
# visit_id                object
# customer_id             object
# visit_date              object
# channel                 object
# dwell_seconds            int64
# is_purchase               bool
# items                   object
# num_items                int64
# total_amount           float64
# total_cogs             float64
# return_flag               bool
# fulfillment_status      object
# satisfaction           float64
# first_visit_date        object
# is_new_customer           bool
# acquisition_channel     object
# Category                object
# dtype: object

# %%
# make the copy of the data
retail_copy = retail.copy(deep = True)
retail_copy.head()
# Out:
#   visit_id customer_id           visit_date     channel  dwell_seconds  \
# 0  V100029       C0297  2025-06-01 02:35:05  E-Commerce            106
# 1  V100255       C0025  2025-06-01 07:26:34       Store            151
# 2  V100057       C0087  2025-06-01 12:08:39  E-Commerce            710
# 3  V100472       C0046  2025-06-02 00:36:32  E-Commerce             62
# 4  V100454       C0169  2025-06-02 07:42:42         App             44
#
#    is_purchase               items  num_items  total_amount  total_cogs  \
# 0         True          Chips (x1)          1          40.0       23.86
# 1         True  Floor Cleaner (x1)          1         180.0      115.54
# 2        False                 NaN          0           0.0        0.00
# 3        False                 NaN          0           0.0        0.00
# 4        False                 NaN          0           0.0        0.00
#
#    return_flag         fulfillment_status  satisfaction     first_visit_date  \
# 0         True                  Fulfilled           2.0  2025-06-01 02:35:05
# 1        False  In-Store Pickup/Immediate           3.0  2025-06-01 07:26:34
# 2        False                        NaN           NaN  2025-06-01 12:08:39
# 3        False                        NaN           NaN  2025-06-02 00:36:32
# 4        False                        NaN           NaN  2025-06-02 07:42:42
#
#    is_new_customer acquisition_channel     Category
# 0             True          E-Commerce  Electronics
# 1             True               Store   Stationery
# 2             True          E-Commerce          NaN
# 3             True          E-Commerce          NaN
# 4             True                 App          NaN

# %%
# Create a new column as Date
retail_copy['Date'] = pd.to_datetime(retail_copy['visit_date'])

# %%
# Customer Footfall
footfalls = retail_copy.groupby(retail_copy['Date'].dt.date)['customer_id'].nunique().sort_values(ascending = False)
print(footfalls)
# Out:
# Date
# 2025-08-18    11
# 2025-07-29    11
# 2025-07-30    10
# 2025-08-09    10
# 2025-08-29     8
#               ..
# 2025-06-26     1
# 2025-06-19     1
# 2025-08-06     1
# 2025-09-02     1
# 2025-09-03     1
# Name: customer_id, Length: 106, dtype: int64

# %%
# Average Dwell Time
avg_dwell = retail_copy.groupby('customer_id')['dwell_seconds'].mean()
round(avg_dwell.mean(),2)
# Out:
# np.float64(268.11)

# %%
# Store layout effectiveness
layout_eff = retail_copy.groupby('Category')['dwell_seconds'].mean().sort_values(ascending = False)
layout_eff
# Out:
# Category
# Grocery        376.187500
# Apparel        321.428571
# Cosmetics      296.954545
# Electronics    274.545455
# Stationery     274.380952
# Name: dwell_seconds, dtype: float64

# %%
# Aggregate tutal spent per customer
customer_spend = retail_copy.groupby('customer_id')['total_amount'].sum().reset_index()
customer_spend.rename(columns = {'total_amount': 'total_spend'}, inplace = True)

# %%
# Percentile Based Spend Score
retail_copy['spend_score'] = (customer_spend['total_spend'] - customer_spend['total_spend'].min()/
                              customer_spend['total_spend'].max() - customer_spend['total_spend'].min()).round(2)

# %%
# See the Spend Score
retail_copy['spend_score'].head()
# Out:
# 0       0.0
# 1       0.0
# 2    3116.0
# 3       0.0
# 4     299.0
# Name: spend_score, dtype: float64

# %%
# Buying Behaviour Classification
def classify_behavior(row):
    if row['spend_score'] > 70 and row['dwell_seconds'] > 40:
        return 'Complex Buying'
    elif row['spend_score'] > 70 and row['dwell_seconds'] <= 40:
        return 'Impulsive Buying'
    elif row['spend_score'] < 40 and row['dwell_seconds'] < 20:
        return 'Habitual Buying'
    else:
        return 'Variety Seeking Buying'

retail_copy['Buying_Behavior'] = retail_copy.apply(classify_behavior, axis=1)

print("Buying Behavior Distribution:")
print(retail_copy['Buying_Behavior'].value_counts(normalize=True) * 100)
# Out:
# Buying Behavior Distribution:
# Buying_Behavior
# Variety Seeking Buying    83.6
# Complex Buying            15.4
# Impulsive Buying           1.0
# Name: proportion, dtype: float64

# %%
# Channel Footfall
channel_footfall = retail_copy.groupby('channel')['customer_id'].nunique().sort_values(ascending = False)
channel_footfall
# Out:
# channel
# Store         153
# E-Commerce    130
# App            99
# Name: customer_id, dtype: int64

# %%
# Conversion rate
conversion_rate = retail_copy.groupby("channel")["is_purchase"].mean().sort_values(ascending = False)
conversion_rate
# Out:
# channel
# Store         0.240566
# E-Commerce    0.206897
# App           0.192982
# Name: is_purchase, dtype: float64

# %%
# Average Order Value based on spend score
aov = retail_copy.groupby('channel')['spend_score'].mean().sort_values(ascending = False)
aov
# Out:
# channel
# E-Commerce    443.341772
# Store         137.634783
# App           103.283333
# Name: spend_score, dtype: float64

# %%
# Return Rate
retail_copy["return_flag"] = retail_copy["return_flag"].astype(int)

return_rate = retail_copy.groupby("channel")["return_flag"].mean() * 100
print("Return Rate by Channel (%):")
print(return_rate.round(2))
# Out:
# Return Rate by Channel (%):
# channel
# App           1.75
# E-Commerce    1.72
# Store         0.47
# Name: return_flag, dtype: float64

# %%
# Omni-channel fulfillment rate (proxy: customers buying in >1 channel)
multi_channel_customers = retail_copy.groupby('customer_id')['channel'].nunique()
omni_rate = (multi_channel_customers  > 1 ).mean()
print('Omni_Channel Fulfillment Rate is', round(omni_rate,2))
# Out:
# Omni_Channel Fulfillment Rate is 0.43

# %%
# Average Customer Satisfaction
if 'satisfaction' in retail_copy.columns:
    satisfaction = retail_copy.groupby('channel')['satisfaction'].mean().sort_values(ascending = False)
    print(satisfaction)
else:
    satisfaction = "Not available"
    print(satisfaction)
# Out:
# channel
# Store         4.176471
# E-Commerce    4.111111
# App           4.045455
# Name: satisfaction, dtype: float64
